# %%
print("select 1 for adding the name of new book in the list and write its position for lending")
print("select 2 for listing name of books and their position")
print("select 3 for lending a book and write the position of the book  as lendt")
print("select 4 for returning a book and putting down on its position as available")

        
nameof_books = ["Savaş ve Barış", "1984", "Bülbülü Öldürmek", "Kırmızı Pazartesi"]
positionof_books = ["Müsait", "Ödünçte", "Müsait", "Müsait"]
while True:
  selection=int(input("select whichever number you want"))
  if selection==1:
     newbook=input("Which book would you like to add?")
     nameof_books.append(newbook)
     positionof_books.append("available")
     print(f"new book name{newbook}and 'available'word is appended into the list")
     
  elif selection==2:
     for i in range(len(nameof_books)):
         print(f"{nameof_books[i]}:{positionof_books[i]}")
  print("the list is above")
         
  elif selection==3:
 
     thelendt_book=input("go for a book for lending")
     if thelendt_book in nameof_books:
       print(nameof_books.index(thelendt_book))
       index=nameof_books.index(thelendt_book)
       if positionof_books[index]=="Müsait":
         positionof_books[index]="Ödünçte"
         print("The book,{},is given to library user and jotted down as 'Ödünçte' book".format(thelendt_book))
       else:
         print("it is not available")
     else:
        print("the book you wanted is not in our library")
         
     for i in range(len(nameof_books)):
       print(f"{nameof_books[i]}:{positionof_books[i]}")
  
   
          
        
  elif selection==4:
     thereturned_book=input("which book do you like to return?")
     if thereturned_book in nameof_books:
       print(nameof_books.index(thereturned_book))
       index=nameof_books.index(thereturned_book)
       if positionof_books[index]=="Ödünçte":
         positionof_books[index]="Musait"
         print("The book,{},is given to library user and available(Müsait) now".format(thereturned_book))
         for i in range(len(nameof_books)):
          print(nameof_books[i],":",positionof_books[i])
       else:
        print("the book you returned is lendt by other user")
     else:
      print("the book you returned is not in our nameof_books list")
   
      
     break
